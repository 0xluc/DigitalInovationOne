# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Gapminder.csv", error_bad_lines=False,sep=';') #cria o objeto df a partir de um arquivo csv
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df = df.rename(columns={"country":"País","continent":"Continente","year":"Ano","lifeExp":"Expectativa de vida","pop":"Pop Total","gdpPercap":"PIB"}) #renomeia as colunas

# %%
df.head(10) #retorna os primeiros membros
# Out:
#           País Continente   Ano  Expectativa de vida  Pop Total         PIB
# 0  Afghanistan       Asia  1952               28.801    8425333  779.445314
# 1  Afghanistan       Asia  1957               30.332    9240934  820.853030
# 2  Afghanistan       Asia  1962               31.997   10267083  853.100710
# 3  Afghanistan       Asia  1967               34.020   11537966  836.197138
# 4  Afghanistan       Asia  1972               36.088   13079460  739.981106
# 5  Afghanistan       Asia  1977               38.438   14880372  786.113360
# 6  Afghanistan       Asia  1982               39.854   12881816  978.011439
# 7  Afghanistan       Asia  1987               40.822   13867957  852.395945
# 8  Afghanistan       Asia  1992               41.674   16317921  649.341395
# 9  Afghanistan       Asia  1997               41.763   22227415  635.341351

# %%
df.shape #numero de linhas e colunas
# Out:
# (3312, 6)

# %%
df.dtypes #retorna os tipos de cada coluna
# Out:
# País                    object
# Continente              object
# Ano                      int64
# Expectativa de vida    float64
# Pop Total                int64
# PIB                    float64
# dtype: object

# %%
df.tail() #retorna os ultimos membros, funciona como a funçao head()
# Out:
#           País Continente   Ano  Expectativa de vida  Pop Total         PIB
# 3307  Zimbabwe     Africa  1987               62.351    9216418  706.157306
# 3308  Zimbabwe     Africa  1992               60.377   10704340  693.420786
# 3309  Zimbabwe     Africa  1997               46.809   11404948  792.449960
# 3310  Zimbabwe     Africa  2002               39.989   11926563  672.038623
# 3311  Zimbabwe     Africa  2007               43.487   12311143  469.709298

# %%
df.describe() #dá algumas relações acerca desse dataset
# Out:
#               Ano  Expectativa de vida     Pop Total            PIB
# count  1704.00000          1704.000000  1.704000e+03    1704.000000
# mean   1979.50000            59.474439  2.960121e+07    7215.327081
# std      17.26533            12.917107  1.061579e+08    9857.454543
# min    1952.00000            23.599000  6.001100e+04     241.165876
# 25%    1965.75000            48.198000  2.793664e+06    1202.060309
# 50%    1979.50000            60.712500  7.023596e+06    3531.846988
# 75%    1993.25000            70.845500  1.958522e+07    9325.462346
# max    2007.00000            82.603000  1.318683e+09  113523.132900

# %%
df["Continente"].unique() #exibe os valores únicos de Continentes
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
Oceania = df.loc[df["Continente"] == "Oceania"] #realiza uma busca e retorna apenas os valores com Continente Oceania
Oceania.head()
# Out:
#      País Continente   Ano  Expectativa de vida  Pop Total          PIB
# 975  Fiji    Oceania  1962               56.494     421869  2039.393277
# 976  Fiji    Oceania  1967               58.607     485000  2170.073285
# 977  Fiji    Oceania  1972               60.642     544000  2797.759484
# 978  Fiji    Oceania  1977               62.669     599339  3182.569600
# 979  Fiji    Oceania  1982               64.683     658906  3209.257468

# %%
df.groupby("Continente")["País"].nunique() #realiza uma contagem de países por continente
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: País, dtype: int64

# %%
df.groupby("Ano")["Expectativa de vida"].mean() #expectativa de vida média para cada ano
# Out:
# Ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283438
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %%
df["PIB"].mean()
# Out:
# 11317.115804696648

# %%
df["PIB"].sum() #soma os PIBS
# Out:
# 37482287.5451553
